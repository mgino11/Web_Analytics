# %% [markdown]
# **Project 3**
#
# ***Group 1: Adam Gersowitz, Diego Correa, Maria Gironio***
#
# Using any of the three classifiers described in chapter 6 of Natural Language Processing with Python, and any features you can think of, build the best name gender classifier you can. Begin by splitting the Names Corpus into three subsets: 500 words for the test set, 500 words for the dev-test set, and the remaining 6900 words for the training set. Then, starting with the example name gender classifier, make incremental improvements. Use the dev-test set to check your progress. Once you are satisfied with your classifier, check its final performance on the test set. How does the performance on the test set compare to the performance on the dev-test set? Is this what you'd expect?

# %% [markdown]
# **Example Name Gender Classifier**
#
# Page 222 in Natural Processing with Python

# %%
import random

random.seed(10)

def gender_features(word):
  return {'last_letter': word[-1]}


import nltk
#nltk.download('names')
from nltk.corpus import names
import random


names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

random.shuffle(names)

featuresets = [(gender_features(n), g) for (n,g) in names] 
train_set, test_set = featuresets[500:], featuresets[:500] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.77

# %% [markdown]
# Improvement from page 227 to help with the second to last letter of a name.

# %%
devtest_names = names[500:1000]
test_names = names[:500]
train_names = names[1000:]

def gender_features(word):
  return {'suffix1': word[-1:],
          'suffix2': word[-2:]}

train_set = [(gender_features(n), g) for (n,g) in train_names]
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names]
test_set = [(gender_features(n), g) for (n,g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)

print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
  print('correct='+tag+' guess='+guess+' name='+name)
# Out:
# 0.77
# correct=female guess=male name=Amargo
# correct=female guess=male name=Blake
# correct=female guess=male name=Brooke
# correct=female guess=male name=Carey
# correct=female guess=male name=Carin
# correct=female guess=male name=Carleen
# correct=female guess=male name=Caro
# correct=female guess=male name=Chloris
# correct=female guess=male name=Christal
# correct=female guess=male name=Clarey
# correct=female guess=male name=Clary
# correct=female guess=male name=Clio
# correct=female guess=male name=Conney
# correct=female guess=male name=Coral
# correct=female guess=male name=Cordey
# correct=female guess=male name=Coriss
# correct=female guess=male name=Cris
# correct=female guess=male name=Dallas
# correct=female guess=male name=Darsey
# correct=female guess=male name=Dolley
# correct=female guess=male name=Doro
# correct=female guess=male name=Drew
# correct=female guess=male name=Eden
# correct=female guess=male name=Eilis
# correct=female guess=male name=Esther
# correct=female guess=male name=Frank
# correct=female guess=male name=Gabbey
# correct=female guess=male name=Gennifer
# correct=female guess=male name=Gill
# correct=female guess=male name=Harley
# correct=female guess=male name=Heather
# correct=female guess=male name=Ines
# correct=female guess=male name=Isabeau
# correct=female guess=male name=Isabel
# correct=female guess=male name=Jackquelin
# correct=female guess=male name=Janean
# correct=female guess=male name=Janeen
# correct=female guess=male name=Janel
# correct=female guess=male name=Joan
# correct=female guess=male name=Karin
# correct=female guess=male name=Kathleen
# correct=female guess=male name=Katleen
# correct=female guess=male name=Keeley
# correct=female guess=male name=Keren
# correct=female guess=male name=Kristen
# correct=female guess=male name=Lacey
# correct=female guess=male name=Laney
# correct=female guess=male name=Lindsey
# correct=female guess=male name=Loreen
# correct=female guess=male name=Madlin
# correct=female guess=male name=Maisey
# correct=female guess=male name=Margalit
# correct=female guess=male name=Margit
# correct=female guess=male name=Margo
# correct=female guess=male name=Mariellen
# correct=female guess=male name=Maryjo
# correct=female guess=male name=Mehetabel
# correct=female guess=male name=Melisent
# correct=female guess=male name=Nancey
# correct=female guess=male name=Pearl
# correct=female guess=male name=Phylis
# correct=female guess=male name=Rochell
# correct=female guess=male name=Scarlett
# correct=female guess=male name=Sharl
# correct=female guess=male name=Shell
# correct=female guess=male name=Sibeal
# correct=female guess=male name=Stoddard
# correct=female guess=male name=Sybil
# correct=female guess=male name=Sydel
# correct=female guess=male name=Trish
# correct=female guess=male name=Yoko
# correct=male guess=female name=Arnie
# correct=male guess=female name=Brody
# correct=male guess=female name=Caryl
# correct=male guess=female name=Chrisy
# correct=male guess=female name=Clemente
# correct=male guess=female name=Cobbie
# correct=male guess=female name=Cyrille
# correct=male guess=female name=Dane
# correct=male guess=female name=Danie
# correct=male guess=female name=Donny
# correct=male guess=female name=Dougie
# correct=male guess=female name=Eddie
# correct=male guess=female name=Geri
# correct=male guess=female name=Hasty
# correct=male guess=female name=Jeffie
# correct=male guess=female name=Jerzy
# correct=male guess=female name=Jodi
# correct=male guess=female name=Joshua
# correct=male guess=female name=Lefty
# correct=male guess=female name=Lonnie
# correct=male guess=female name=Lyle
# correct=male guess=female name=Mackenzie
# correct=male guess=female name=Maxie
# correct=male guess=female name=Morrie
# correct=male guess=female name=Obadiah
# correct=male guess=female name=Paige
# correct=male guess=female name=Pierre
# correct=male guess=female name=Roice
# correct=male guess=female name=Rudie
# correct=male guess=female name=Sarge
# correct=male guess=female name=Sibyl
# correct=male guess=female name=Sterne
# correct=male guess=female name=Tabbie
# correct=male guess=female name=Terrance
# correct=male guess=female name=Torrence
# correct=male guess=female name=Townie
# correct=male guess=female name=Tracy
# correct=male guess=female name=Virge
# correct=male guess=female name=Wallache
# correct=male guess=female name=Waverly
# correct=male guess=female name=Worthy
# correct=male guess=female name=Wylie
# correct=male guess=female name=Zane
# correct=male guess=female name=Zebadiah

# %% [markdown]
# We can see from the output above that there are some names that have been incorectly classified in the same way that start with the same letter (i.e. 13 incorrect guesses of male on female names that start with "C"). We will add the first and second letter of the name as features in our classifier.
#
# This resulted in an improvement from 0.77 accuracy to 0.82 in our devtest set.

# %%
def gender_features(word):
  return {'suffix1': word[-1:],
          'suffix2': word[-2:],
          'prefix1': word[:1],
          'prefix2': word[:2]}


train_set = [(gender_features(n), g) for (n,g) in train_names]
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names]
test_set = [(gender_features(n), g) for (n,g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
  print('correct='+tag+' guess='+guess+' name='+name)
# Out:
# 0.82
# correct=female guess=male name=Amargo
# correct=female guess=male name=Brooke
# correct=female guess=male name=Caro
# correct=female guess=male name=Chloris
# correct=female guess=male name=Clio
# correct=female guess=male name=Coriss
# correct=female guess=male name=Cris
# correct=female guess=male name=Dallas
# correct=female guess=male name=Doro
# correct=female guess=male name=Drew
# correct=female guess=male name=Eden
# correct=female guess=male name=Esther
# correct=female guess=male name=Frank
# correct=female guess=male name=Gabbey
# correct=female guess=male name=Gennifer
# correct=female guess=male name=Gill
# correct=female guess=male name=Harley
# correct=female guess=male name=Harlie
# correct=female guess=male name=Heather
# correct=female guess=male name=Ines
# correct=female guess=male name=Isabeau
# correct=female guess=male name=Isabel
# correct=female guess=male name=Jackquelin
# correct=female guess=male name=Janean
# correct=female guess=male name=Joan
# correct=female guess=male name=Madlin
# correct=female guess=male name=Margalit
# correct=female guess=male name=Margit
# correct=female guess=male name=Margo
# correct=female guess=male name=Melisent
# correct=female guess=male name=Pammy
# correct=female guess=male name=Pearl
# correct=female guess=male name=Phylis
# correct=female guess=male name=Queenie
# correct=female guess=male name=Rochell
# correct=female guess=male name=Scarlett
# correct=female guess=male name=Sharl
# correct=female guess=male name=Shell
# correct=female guess=male name=Sibeal
# correct=female guess=male name=Stoddard
# correct=female guess=male name=Sybil
# correct=female guess=male name=Sydel
# correct=female guess=male name=Trish
# correct=female guess=male name=Trudy
# correct=male guess=female name=Andrey
# correct=male guess=female name=Arnie
# correct=male guess=female name=Brody
# correct=male guess=female name=Caryl
# correct=male guess=female name=Chrisy
# correct=male guess=female name=Clemente
# correct=male guess=female name=Cobbie
# correct=male guess=female name=Corky
# correct=male guess=female name=Cyrille
# correct=male guess=female name=Dane
# correct=male guess=female name=Danie
# correct=male guess=female name=Darren
# correct=male guess=female name=Dewey
# correct=male guess=female name=Donal
# correct=male guess=female name=Donny
# correct=male guess=female name=Dougie
# correct=male guess=female name=Eddie
# correct=male guess=female name=Emmet
# correct=male guess=female name=Finley
# correct=male guess=female name=Geri
# correct=male guess=female name=Jeffie
# correct=male guess=female name=Jerzy
# correct=male guess=female name=Jodi
# correct=male guess=female name=Joshua
# correct=male guess=female name=Kerry
# correct=male guess=female name=Konstantin
# correct=male guess=female name=Lefty
# correct=male guess=female name=Lonnie
# correct=male guess=female name=Luke
# correct=male guess=female name=Lyle
# correct=male guess=female name=Mackenzie
# correct=male guess=female name=Maxie
# correct=male guess=female name=Michael
# correct=male guess=female name=Mikey
# correct=male guess=female name=Morrie
# correct=male guess=female name=Nicky
# correct=male guess=female name=Roice
# correct=male guess=female name=Rudie
# correct=male guess=female name=Sarge
# correct=male guess=female name=Sibyl
# correct=male guess=female name=Sterne
# correct=male guess=female name=Tabbie
# correct=male guess=female name=Terrance
# correct=male guess=female name=Townie
# correct=male guess=female name=Virge
# correct=male guess=female name=Zane

# %% [markdown]
# We will try to add vowel count as a possible feature. When added to the classifier vowle count actually decreases our accuracy so it will not be added to the final classifier.
#
# Vowel count coe: https://www.delftstack.com/howto/python/python-syllable-counter/

# %%
def v_count(str):
    count = 0
    
    syllables = set("AEIOUaeiou")
    
    for letter in str:
        if letter in syllables:
            count = count + 1
    return count

def gender_features(word):
  vowel_count = v_count(word)
  return {'suffix1': word[-1:],
          'suffix2': word[-2:],
          'prefix1': word[:1],
          'prefix2': word[:2],
          'vowel_count': vowel_count
          }

train_set = [(gender_features(n), g) for (n,g) in train_names]
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names]
test_set = [(gender_features(n), g) for (n,g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


#for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
#  print('correct='+tag+' guess='+guess+' name='+name)
# Out:
# 0.812

# %% [markdown]
# After returning to the list of incorrect guesses we find that there are a few examples of female names that have repeating letters ("Pammy","Gennifer","Gabby") so we will add a feature that will determine if there are back to back letters in a name.
#
# This upped the accuracy a bit to 0.822.
#
# Code source: https://stackoverflow.com/questions/34443946/count-consecutive-characters

# %%
from itertools import groupby




def gender_features(word):
  groups = groupby(word)
  result = [(label, sum(1 for _ in group)) for label, group in groups]
  result=", ".join("{}x{}".format(label, count) for label, count in result)
  rep= "2" in result
  return {'suffix1': word[-1:],
          'suffix2': word[-2:],
          'prefix1': word[:1],
          'prefix2': word[:2],
          'repeat': rep
          }

        

train_set = [(gender_features(n), g) for (n,g) in train_names]
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names]
test_set = [(gender_features(n), g) for (n,g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


#for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
#  print('correct='+tag+' guess='+guess+' name='+name)
# Out:
# 0.822

# %% [markdown]
# We will also add the third letter and the third to last letter of the names in order to better find patterns in the names that we can not identify. We will stop at 3 so we avoid overfitting the model to the test set. This increases our accuracy to 0.848.
#
# At this point we will also take a deeper look at the most informative features by looking at the top 100. We can see that the suffix and prefix features are much mroe helpful then the repeating letter feature so we will remove the repeating letter feature to avoid overfitting.

# %%
def gender_features(word):
  groups = groupby(word)
  result = [(label, sum(1 for _ in group)) for label, group in groups]
  result=", ".join("{}x{}".format(label, count) for label, count in result)
  rep= "2" in result
  return {'suffix1': word[-1:],
          'suffix2': word[-2:],
          'suffix3': word[-3:],
          'prefix1': word[:1],
          'prefix2': word[:2],
          'prefix3': word[:3],
          'repeat': rep
          }


classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


#for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
#  print('correct='+tag+' guess='+guess+' name='+name)


classifier.show_most_informative_features(100)
# Out:
# 0.822
# Most Informative Features
#                  suffix2 = 'na'           female : male   =     94.0 : 1.0
#                  suffix2 = 'la'           female : male   =     69.0 : 1.0
#                  suffix1 = 'k'              male : female =     41.8 : 1.0
#                  suffix2 = 'ia'           female : male   =     37.6 : 1.0
#                  suffix1 = 'a'            female : male   =     34.7 : 1.0
#                  suffix2 = 'rd'             male : female =     30.7 : 1.0
#                  suffix2 = 'us'             male : female =     27.9 : 1.0
#                  suffix2 = 'ra'           female : male   =     25.5 : 1.0
#                  suffix2 = 'do'             male : female =     25.0 : 1.0
#                  suffix2 = 'ta'           female : male   =     23.3 : 1.0
#                  suffix2 = 'rt'             male : female =     22.1 : 1.0
#                  suffix2 = 'ld'             male : female =     21.7 : 1.0
#                  suffix2 = 'os'             male : female =     19.4 : 1.0
#                  prefix2 = 'Hu'             male : female =     17.3 : 1.0
#                  prefix2 = 'Fo'             male : female =     16.2 : 1.0
#                  suffix1 = 'f'              male : female =     14.6 : 1.0
#                  suffix2 = 'ch'             male : female =     14.3 : 1.0
#                  suffix2 = 'ka'           female : male   =     14.2 : 1.0
#                  suffix2 = 'ro'             male : female =     13.9 : 1.0
#                  suffix1 = 'p'              male : female =     12.6 : 1.0
#                  prefix2 = 'Ya'             male : female =     10.6 : 1.0
#                  prefix2 = 'Tu'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ce'           female : male   =     10.6 : 1.0
#                  suffix2 = 'ew'             male : female =     10.6 : 1.0
#                  suffix2 = 'ip'             male : female =     10.6 : 1.0
#                  suffix2 = 'em'             male : female =     10.6 : 1.0
#                  suffix1 = 'v'              male : female =     10.5 : 1.0
#                  suffix2 = 'im'             male : female =     10.3 : 1.0
#                  suffix1 = 'o'              male : female =     10.0 : 1.0
#                  suffix1 = 'd'              male : female =      9.9 : 1.0
#                  suffix2 = 'rn'             male : female =      9.4 : 1.0
#                  suffix2 = 'ff'             male : female =      9.4 : 1.0
#                  suffix2 = 'ns'             male : female =      9.4 : 1.0
#                  suffix2 = 'ya'           female : male   =      9.4 : 1.0
#                  suffix2 = 'as'             male : female =      9.2 : 1.0
#                  suffix1 = 'm'              male : female =      9.2 : 1.0
#                  suffix2 = 'ti'           female : male   =      9.0 : 1.0
#                  suffix2 = 'on'             male : female =      8.6 : 1.0
#                  prefix2 = 'Wh'             male : female =      8.4 : 1.0
#                  suffix2 = 'ul'             male : female =      8.3 : 1.0
#                  suffix2 = 'st'             male : female =      8.3 : 1.0
#                  suffix2 = 'rk'             male : female =      8.3 : 1.0
#                  suffix2 = 'ea'           female : male   =      8.3 : 1.0
#                  suffix2 = 'di'           female : male   =      8.3 : 1.0
#                  suffix2 = 'er'             male : female =      8.2 : 1.0
#                  suffix2 = 'am'             male : female =      7.4 : 1.0
#                  prefix2 = 'Wa'             male : female =      7.4 : 1.0
#                  suffix2 = 'sy'           female : male   =      7.1 : 1.0
#                  suffix1 = 'r'              male : female =      6.7 : 1.0
#                  suffix2 = 'ar'             male : female =      6.5 : 1.0
#                  suffix2 = 'es'             male : female =      6.3 : 1.0
#                  suffix2 = 'ud'             male : female =      6.3 : 1.0
#                  suffix2 = 'sh'             male : female =      6.3 : 1.0
#                  suffix2 = 'te'           female : male   =      6.3 : 1.0
#                  suffix2 = 'oy'             male : female =      6.1 : 1.0
#                  suffix2 = 'eb'             male : female =      6.1 : 1.0
#                  suffix2 = 'ev'             male : female =      6.1 : 1.0
#                  suffix2 = 'lo'             male : female =      5.9 : 1.0
#                  suffix1 = 'w'              male : female =      5.9 : 1.0
#                  suffix2 = 'si'           female : male   =      5.8 : 1.0
#                  suffix2 = 'ke'             male : female =      5.8 : 1.0
#                  suffix2 = 'ha'           female : male   =      5.7 : 1.0
#                  prefix2 = 'Sc'             male : female =      5.7 : 1.0
#                  prefix2 = 'Ka'           female : male   =      5.5 : 1.0
#                  suffix2 = 'ed'             male : female =      5.3 : 1.0
#                  prefix2 = 'We'             male : female =      5.2 : 1.0
#                  suffix2 = 'ee'           female : male   =      5.2 : 1.0
#                  prefix2 = 'Fa'           female : male   =      5.1 : 1.0
#                  suffix2 = 'ni'           female : male   =      5.1 : 1.0
#                  suffix2 = 'ig'             male : female =      5.0 : 1.0
#                  suffix1 = 'u'              male : female =      4.7 : 1.0
#                  suffix2 = 'nt'             male : female =      4.6 : 1.0
#                  suffix2 = 'or'             male : female =      4.5 : 1.0
#                  suffix1 = 'g'              male : female =      4.5 : 1.0
#                  prefix1 = 'W'              male : female =      4.4 : 1.0
#                  suffix1 = 'z'              male : female =      4.3 : 1.0
#                  suffix2 = 'nd'             male : female =      4.3 : 1.0
#                  prefix2 = 'Ze'             male : female =      4.3 : 1.0
#                  suffix2 = 'yn'           female : male   =      4.3 : 1.0
#                  prefix2 = 'Ly'           female : male   =      4.2 : 1.0
#                  suffix1 = 's'              male : female =      4.1 : 1.0
#                  suffix2 = 'ad'             male : female =      4.1 : 1.0
#                  suffix2 = 'ne'           female : male   =      4.1 : 1.0
#                  prefix2 = 'Ty'             male : female =      4.1 : 1.0
#                  suffix2 = 'eo'             male : female =      4.0 : 1.0
#                  prefix2 = 'Dr'             male : female =      3.9 : 1.0
#                  suffix2 = 'vi'             male : female =      3.9 : 1.0
#                  suffix2 = 'ax'             male : female =      3.9 : 1.0
#                  suffix2 = 'so'             male : female =      3.9 : 1.0
#                  suffix1 = 't'              male : female =      3.8 : 1.0
#                  prefix2 = 'Bu'             male : female =      3.8 : 1.0
#                  suffix2 = 'ba'           female : male   =      3.8 : 1.0
#                  prefix2 = 'Ky'           female : male   =      3.8 : 1.0
#                  prefix2 = 'Su'           female : male   =      3.8 : 1.0
#                  prefix2 = 'Gl'           female : male   =      3.7 : 1.0
#                  suffix1 = 'b'              male : female =      3.7 : 1.0
#                  prefix2 = 'Li'           female : male   =      3.6 : 1.0
#                  prefix2 = 'Rh'           female : male   =      3.4 : 1.0
#                  suffix1 = 'i'            female : male   =      3.3 : 1.0
#                  prefix2 = 'Ru'             male : female =      3.3 : 1.0

# %% [markdown]
# The removal of the repeating letter feature did not reduce our accuract of 0.848.
#
# We will add a general measure of the vowels and consanants that are not the first letter of the name (by only pulling lower case)  to see if a collection of these letters helps us determine the gender. We can see this increases our accuracy to 0.854. We can also see when examining the most impactful features that these measures fall iwthin the top 100 features so we will keep them.

# %%
import re

def gender_features(word):
  vowels = "".join(sorted(list(set(re.sub(r'[^aeiou]', '', word)))))
  consonants = "".join(sorted(list(set(re.sub(r'[aeiou]', '', word)))))
  return {'suffix1': word[-1:],
          'suffix2': word[-2:],
          'suffix3': word[-3:],
          'prefix1': word[:1],
          'prefix2': word[:2],
          'prefix3': word[:3],
          'vow':vowels,
          'con': consonants
          }

          
train_set = [(gender_features(n), g) for (n,g) in train_names]
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names]
test_set = [(gender_features(n), g) for (n,g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)

print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


classifier.show_most_informative_features(100)

#for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
#  print('correct='+tag+' guess='+guess+' name='+name)
# Out:
# 0.854
# Most Informative Features
#                  suffix2 = 'na'           female : male   =     94.0 : 1.0
#                  suffix2 = 'la'           female : male   =     69.0 : 1.0
#                  suffix1 = 'k'              male : female =     41.8 : 1.0
#                  suffix2 = 'ia'           female : male   =     37.6 : 1.0
#                  suffix1 = 'a'            female : male   =     34.7 : 1.0
#                  suffix2 = 'rd'             male : female =     30.7 : 1.0
#                  suffix3 = 'ard'            male : female =     28.8 : 1.0
#                  suffix2 = 'us'             male : female =     27.9 : 1.0
#                  suffix3 = 'ana'          female : male   =     25.6 : 1.0
#                  suffix2 = 'ra'           female : male   =     25.5 : 1.0
#                  suffix2 = 'do'             male : female =     25.0 : 1.0
#                  suffix3 = 'tta'          female : male   =     23.9 : 1.0
#                  suffix2 = 'ta'           female : male   =     23.3 : 1.0
#                  suffix2 = 'rt'             male : female =     22.1 : 1.0
#                  suffix2 = 'ld'             male : female =     21.7 : 1.0
#                  suffix3 = 'nne'          female : male   =     19.8 : 1.0
#                  suffix2 = 'os'             male : female =     19.4 : 1.0
#                  prefix2 = 'Hu'             male : female =     17.3 : 1.0
#                  prefix2 = 'Fo'             male : female =     16.2 : 1.0
#                  suffix3 = 'vin'            male : female =     16.0 : 1.0
#                  prefix3 = 'Tha'            male : female =     15.1 : 1.0
#                  suffix3 = 'old'            male : female =     15.0 : 1.0
#                  suffix1 = 'f'              male : female =     14.6 : 1.0
#                  suffix3 = 'ela'          female : male   =     14.4 : 1.0
#                  suffix2 = 'ch'             male : female =     14.3 : 1.0
#                  suffix2 = 'ka'           female : male   =     14.2 : 1.0
#                  suffix3 = 'ita'          female : male   =     14.1 : 1.0
#                  suffix2 = 'ro'             male : female =     13.9 : 1.0
#                  suffix3 = 'dra'          female : male   =     13.1 : 1.0
#                      vow = 'iou'            male : female =     13.0 : 1.0
#                  suffix1 = 'p'              male : female =     12.6 : 1.0
#                  prefix3 = 'Cat'          female : male   =     12.2 : 1.0
#                  suffix3 = 'ert'            male : female =     11.7 : 1.0
#                      con = 'Jln'          female : male   =     11.6 : 1.0
#                  suffix3 = 'ria'          female : male   =     11.4 : 1.0
#                      con = 'Lnr'          female : male   =     11.1 : 1.0
#                  suffix3 = 'nni'          female : male   =     11.0 : 1.0
#                  prefix3 = 'Dor'          female : male   =     10.6 : 1.0
#                  prefix2 = 'Tu'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ya'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ce'           female : male   =     10.6 : 1.0
#                  suffix2 = 'ip'             male : female =     10.6 : 1.0
#                  suffix2 = 'em'             male : female =     10.6 : 1.0
#                  suffix2 = 'ew'             male : female =     10.6 : 1.0
#                  suffix1 = 'v'              male : female =     10.5 : 1.0
#                  suffix3 = 'son'            male : female =     10.5 : 1.0
#                      vow = 'ou'             male : female =     10.4 : 1.0
#                  prefix3 = 'Ros'          female : male   =     10.4 : 1.0
#                  suffix2 = 'im'             male : female =     10.3 : 1.0
#                  prefix3 = 'Rod'            male : female =     10.3 : 1.0
#                  suffix1 = 'o'              male : female =     10.0 : 1.0
#                  suffix1 = 'd'              male : female =      9.9 : 1.0
#                  suffix3 = 'dor'            male : female =      9.8 : 1.0
#                  suffix3 = 'han'            male : female =      9.8 : 1.0
#                  suffix3 = 'cia'          female : male   =      9.7 : 1.0
#                  prefix3 = 'Jen'          female : male   =      9.6 : 1.0
#                  prefix3 = 'Gar'            male : female =      9.6 : 1.0
#                  suffix2 = 'ns'             male : female =      9.4 : 1.0
#                  suffix2 = 'rn'             male : female =      9.4 : 1.0
#                  suffix2 = 'ff'             male : female =      9.4 : 1.0
#                  suffix2 = 'ya'           female : male   =      9.4 : 1.0
#                      con = 'Rd'             male : female =      9.3 : 1.0
#                  suffix2 = 'as'             male : female =      9.2 : 1.0
#                  suffix1 = 'm'              male : female =      9.2 : 1.0
#                  suffix2 = 'ti'           female : male   =      9.0 : 1.0
#                  suffix3 = 'ias'            male : female =      8.8 : 1.0
#                  suffix3 = 'den'            male : female =      8.8 : 1.0
#                  suffix3 = 'ler'            male : female =      8.8 : 1.0
#                  suffix2 = 'on'             male : female =      8.6 : 1.0
#                  suffix3 = 'lyn'          female : male   =      8.6 : 1.0
#                      con = 'Cnr'          female : male   =      8.4 : 1.0
#                  prefix2 = 'Wh'             male : female =      8.4 : 1.0
#                  suffix2 = 'rk'             male : female =      8.3 : 1.0
#                  suffix2 = 'ul'             male : female =      8.3 : 1.0
#                  suffix2 = 'st'             male : female =      8.3 : 1.0
#                      con = 'Wdln'           male : female =      8.3 : 1.0
#                  suffix3 = 'ter'            male : female =      8.3 : 1.0
#                  suffix2 = 'ea'           female : male   =      8.3 : 1.0
#                  suffix2 = 'di'           female : male   =      8.3 : 1.0
#                  suffix3 = 'lle'          female : male   =      8.2 : 1.0
#                  suffix2 = 'er'             male : female =      8.2 : 1.0
#                  prefix3 = 'God'            male : female =      7.8 : 1.0
#                  prefix3 = 'For'            male : female =      7.8 : 1.0
#                  prefix3 = 'Par'            male : female =      7.8 : 1.0
#                  prefix3 = 'Lor'          female : male   =      7.8 : 1.0
#                  suffix3 = 'ven'            male : female =      7.7 : 1.0
#                  suffix3 = 'uel'            male : female =      7.7 : 1.0
#                  suffix3 = 'las'            male : female =      7.7 : 1.0
#                  suffix3 = 'lli'          female : male   =      7.5 : 1.0
#                  prefix3 = 'Mal'          female : male   =      7.5 : 1.0
#                  suffix2 = 'am'             male : female =      7.4 : 1.0
#                  suffix3 = 'ene'          female : male   =      7.4 : 1.0
#                  prefix2 = 'Wa'             male : female =      7.4 : 1.0
#                      con = 'Gdr'            male : female =      7.3 : 1.0
#                      con = 'Rdln'           male : female =      7.3 : 1.0
#                  suffix3 = 'bel'          female : male   =      7.1 : 1.0
#                  suffix2 = 'sy'           female : male   =      7.1 : 1.0
#                  suffix3 = 'lee'          female : male   =      6.9 : 1.0
#                  prefix3 = 'Kar'          female : male   =      6.9 : 1.0
#                  prefix3 = 'Whi'            male : female =      6.8 : 1.0

# %% [markdown]
# To narrow down the scope of the consonants and vowels we will introduce digraphs and trigraphs. Digrpahs and Trigraphs are a string of 2 or 3 letters in english that typically make a unique sound. we will test these at the beginning and end of the name as well as all of the graphs in a name. Some of these digraph features arein our top 100 and it increases our accuracy to 0.858.
#
#
# https://www.enchantedlearning.com/consonantblends/

# %%
digraphs=['bl', 'br', 'ch', 'ck', 'cl', 'cr', 'dr', 'fl', 'fr', 'gh', 'gl', 'gr', 'ng', 'ph', 'pl', 'pr', 'qu', 'sc', 'sh', 'sk', 'sl', 'sm', 'sn', 'sp', 'st', 'sw', 'th', 'tr', 'tw', 'wh', 'wr']
trigraphs= ['nth', 'sch', 'scr', 'shr', 'spl', 'spr', 'squ', 'str', 'thr']
v_digraphs= ['ai', 'au', 'aw', 'ay', 'ea', 'ee', 'ei', 'eu', 'ew', 'ey', 'ie', 'oi', 'oo', 'ou', 'ow', 'oy']





def gender_features(word):
  #vowels = "".join(sorted(list(set(re.sub(r'[^aeiou]', '', word)))))
  #consonants = "".join(sorted(list(set(re.sub(r'[aeiou]', '', word)))))
  resdi = "".join([ele for ele in digraphs if(ele in word)])
  restri = "".join([ele for ele in trigraphs if(ele in word)])
  resvdi = "".join([ele for ele in v_digraphs if(ele in word)])
  endresdi = "".join([ele for ele in digraphs if(ele in word[-2:])])
  endrestri = "".join([ele for ele in trigraphs if(ele in word[-3:])])
  endresvdi = "".join([ele for ele in v_digraphs if(ele in word[-2:])])
  startresdi = "".join([ele for ele in digraphs if(ele in word.lower()[:2])])
  startrestri = "".join([ele for ele in trigraphs if(ele in word.lower()[:3])])
  startresvdi = "".join([ele for ele in v_digraphs if(ele in word.lower()[:2])])
  return {'suffix1': word[-1:],
          'suffix2': word[-2:],
          'suffix3': word[-3:],
          'prefix1': word[:1],
          'prefix2': word[:2],
          'prefix3': word[:3],
          #'vow':vowels,
          #'con': consonants,
          'digraphs': resdi,
          'trigraphs': restri,
          'vowel_digraphs': resvdi,
          'end_digraphs': endresdi,
          'end_trigraphs': endrestri,
          'end_vowel_digraphs': endresvdi,
          'start_digraphs': startresdi,
          'start_trigraphs': startrestri,
          'start_vowel_digraphs': startresvdi
          }

         


train_set = [(gender_features(n), g) for (n,g) in train_names]
devtest_set = [(gender_features(n), g) for (n,g) in devtest_names]
test_set = [(gender_features(n), g) for (n,g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)

print(nltk.classify.accuracy(classifier, devtest_set))



errors = []
for (name, tag) in devtest_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


classifier.show_most_informative_features(100)
# Out:
# 0.858
# Most Informative Features
#                  suffix2 = 'na'           female : male   =     94.0 : 1.0
#                  suffix2 = 'la'           female : male   =     69.0 : 1.0
#                  suffix1 = 'k'              male : female =     41.8 : 1.0
#                  suffix2 = 'ia'           female : male   =     37.6 : 1.0
#                  suffix1 = 'a'            female : male   =     34.7 : 1.0
#                  suffix2 = 'rd'             male : female =     30.7 : 1.0
#                  suffix3 = 'ard'            male : female =     28.8 : 1.0
#                  suffix2 = 'us'             male : female =     27.9 : 1.0
#                  suffix3 = 'ana'          female : male   =     25.6 : 1.0
#                  suffix2 = 'ra'           female : male   =     25.5 : 1.0
#                  suffix2 = 'do'             male : female =     25.0 : 1.0
#                  suffix3 = 'tta'          female : male   =     23.9 : 1.0
#                  suffix2 = 'ta'           female : male   =     23.3 : 1.0
#                  suffix2 = 'rt'             male : female =     22.1 : 1.0
#                  suffix2 = 'ld'             male : female =     21.7 : 1.0
#                  suffix3 = 'nne'          female : male   =     19.8 : 1.0
#                  suffix2 = 'os'             male : female =     19.4 : 1.0
#                  prefix2 = 'Hu'             male : female =     17.3 : 1.0
#                  prefix2 = 'Fo'             male : female =     16.2 : 1.0
#                  suffix3 = 'vin'            male : female =     16.0 : 1.0
#                  prefix3 = 'Tha'            male : female =     15.1 : 1.0
#                  suffix3 = 'old'            male : female =     15.0 : 1.0
#             end_digraphs = 'ch'             male : female =     14.6 : 1.0
#                  suffix1 = 'f'              male : female =     14.6 : 1.0
#                  suffix3 = 'ela'          female : male   =     14.4 : 1.0
#                  suffix2 = 'ch'             male : female =     14.3 : 1.0
#                  suffix2 = 'ka'           female : male   =     14.2 : 1.0
#                  suffix3 = 'ita'          female : male   =     14.1 : 1.0
#                  suffix2 = 'ro'             male : female =     13.9 : 1.0
#                  suffix3 = 'dra'          female : male   =     13.1 : 1.0
#                  suffix1 = 'p'              male : female =     12.6 : 1.0
#                  prefix3 = 'Cat'          female : male   =     12.2 : 1.0
#                  suffix3 = 'ert'            male : female =     11.7 : 1.0
#                  suffix3 = 'ria'          female : male   =     11.4 : 1.0
#                  suffix3 = 'nni'          female : male   =     11.0 : 1.0
#       end_vowel_digraphs = 'ew'             male : female =     10.8 : 1.0
#                  prefix3 = 'Dor'          female : male   =     10.6 : 1.0
#                  prefix2 = 'Tu'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ya'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ce'           female : male   =     10.6 : 1.0
#                  suffix2 = 'ip'             male : female =     10.6 : 1.0
#                  suffix2 = 'em'             male : female =     10.6 : 1.0
#                  suffix2 = 'ew'             male : female =     10.6 : 1.0
#                  suffix1 = 'v'              male : female =     10.5 : 1.0
#                  suffix3 = 'son'            male : female =     10.5 : 1.0
#                  prefix3 = 'Ros'          female : male   =     10.4 : 1.0
#                  suffix2 = 'im'             male : female =     10.3 : 1.0
#                  prefix3 = 'Rod'            male : female =     10.3 : 1.0
#                  suffix1 = 'o'              male : female =     10.0 : 1.0
#                  suffix1 = 'd'              male : female =      9.9 : 1.0
#                  suffix3 = 'han'            male : female =      9.8 : 1.0
#                  suffix3 = 'dor'            male : female =      9.8 : 1.0
#                  suffix3 = 'cia'          female : male   =      9.7 : 1.0
#                  prefix3 = 'Jen'          female : male   =      9.6 : 1.0
#                  prefix3 = 'Gar'            male : female =      9.6 : 1.0
#                  suffix2 = 'ns'             male : female =      9.4 : 1.0
#                  suffix2 = 'rn'             male : female =      9.4 : 1.0
#                  suffix2 = 'ff'             male : female =      9.4 : 1.0
#                  suffix2 = 'ya'           female : male   =      9.4 : 1.0
#                  suffix2 = 'as'             male : female =      9.2 : 1.0
#                  suffix1 = 'm'              male : female =      9.2 : 1.0
#                  suffix2 = 'ti'           female : male   =      9.0 : 1.0
#           vowel_digraphs = 'ew'             male : female =      9.0 : 1.0
#                  suffix3 = 'ler'            male : female =      8.8 : 1.0
#                  suffix3 = 'ias'            male : female =      8.8 : 1.0
#                  suffix3 = 'den'            male : female =      8.8 : 1.0
#                  suffix2 = 'on'             male : female =      8.6 : 1.0
#                  suffix3 = 'lyn'          female : male   =      8.6 : 1.0
#             end_digraphs = 'st'             male : female =      8.5 : 1.0
#           start_digraphs = 'wh'             male : female =      8.5 : 1.0
#                  prefix2 = 'Wh'             male : female =      8.4 : 1.0
#                  suffix2 = 'st'             male : female =      8.3 : 1.0
#                  suffix2 = 'rk'             male : female =      8.3 : 1.0
#                  suffix2 = 'ul'             male : female =      8.3 : 1.0
#                  suffix3 = 'ter'            male : female =      8.3 : 1.0
#                  suffix2 = 'ea'           female : male   =      8.3 : 1.0
#                  suffix2 = 'di'           female : male   =      8.3 : 1.0
#                  suffix3 = 'lle'          female : male   =      8.2 : 1.0
#                  suffix2 = 'er'             male : female =      8.2 : 1.0
#       end_vowel_digraphs = 'ea'           female : male   =      8.1 : 1.0
#                  prefix3 = 'God'            male : female =      7.8 : 1.0
#                  prefix3 = 'For'            male : female =      7.8 : 1.0
#                  prefix3 = 'Par'            male : female =      7.8 : 1.0
#                  prefix3 = 'Lor'          female : male   =      7.8 : 1.0
#                  suffix3 = 'ven'            male : female =      7.7 : 1.0
#                  suffix3 = 'uel'            male : female =      7.7 : 1.0
#                  suffix3 = 'las'            male : female =      7.7 : 1.0
#                  suffix3 = 'lli'          female : male   =      7.5 : 1.0
#                  prefix3 = 'Mal'          female : male   =      7.5 : 1.0
#                  suffix2 = 'am'             male : female =      7.4 : 1.0
#                  suffix3 = 'ene'          female : male   =      7.4 : 1.0
#                  prefix2 = 'Wa'             male : female =      7.4 : 1.0
#                  suffix3 = 'bel'          female : male   =      7.1 : 1.0
#                  suffix2 = 'sy'           female : male   =      7.1 : 1.0
#           vowel_digraphs = 'oo'             male : female =      6.9 : 1.0
#                  suffix3 = 'lee'          female : male   =      6.9 : 1.0
#                  prefix3 = 'Kar'          female : male   =      6.9 : 1.0
#                  prefix3 = 'Whi'            male : female =      6.8 : 1.0
#                  prefix3 = 'Bur'            male : female =      6.8 : 1.0
#                  prefix3 = 'Kin'            male : female =      6.8 : 1.0

# %% [markdown]
# Now with this list of features we will evaluate our classifier against the testing set. We get a slightly worse accuracy of 0.826 which implies some possible slight overfitting to the dev_test set. An additional way to expand this classifier is by identifiying and applying different features to the names if they can be bucketed into languages of origin (i.e. "Georgiamay", "Hpephzibah", "Bobby", "Andrei" may be derived from different languages originally and thus may have different rules for the gender idneticifaction of their names).
#
# However an accuracy of 82.6% is a good classifier and anything much higher would likely suffer from overfitting.

# %%
print(nltk.classify.accuracy(classifier, test_set))

errors = []
for (name, tag) in test_names:
  guess = classifier.classify(gender_features(name)) 
  if guess != tag:
    errors.append( (tag, guess, name) )


classifier.show_most_informative_features(100)

for (tag, guess, name) in sorted(errors): # doctest: +ELLIPSIS +NORMALIZE_WHITESPACE ...
  print('correct='+tag+' guess='+guess+' name='+name)
# Out:
# 0.826
# Most Informative Features
#                  suffix2 = 'na'           female : male   =     94.0 : 1.0
#                  suffix2 = 'la'           female : male   =     69.0 : 1.0
#                  suffix1 = 'k'              male : female =     41.8 : 1.0
#                  suffix2 = 'ia'           female : male   =     37.6 : 1.0
#                  suffix1 = 'a'            female : male   =     34.7 : 1.0
#                  suffix2 = 'rd'             male : female =     30.7 : 1.0
#                  suffix3 = 'ard'            male : female =     28.8 : 1.0
#                  suffix2 = 'us'             male : female =     27.9 : 1.0
#                  suffix3 = 'ana'          female : male   =     25.6 : 1.0
#                  suffix2 = 'ra'           female : male   =     25.5 : 1.0
#                  suffix2 = 'do'             male : female =     25.0 : 1.0
#                  suffix3 = 'tta'          female : male   =     23.9 : 1.0
#                  suffix2 = 'ta'           female : male   =     23.3 : 1.0
#                  suffix2 = 'rt'             male : female =     22.1 : 1.0
#                  suffix2 = 'ld'             male : female =     21.7 : 1.0
#                  suffix3 = 'nne'          female : male   =     19.8 : 1.0
#                  suffix2 = 'os'             male : female =     19.4 : 1.0
#                  prefix2 = 'Hu'             male : female =     17.3 : 1.0
#                  prefix2 = 'Fo'             male : female =     16.2 : 1.0
#                  suffix3 = 'vin'            male : female =     16.0 : 1.0
#                  prefix3 = 'Tha'            male : female =     15.1 : 1.0
#                  suffix3 = 'old'            male : female =     15.0 : 1.0
#             end_digraphs = 'ch'             male : female =     14.6 : 1.0
#                  suffix1 = 'f'              male : female =     14.6 : 1.0
#                  suffix3 = 'ela'          female : male   =     14.4 : 1.0
#                  suffix2 = 'ch'             male : female =     14.3 : 1.0
#                  suffix2 = 'ka'           female : male   =     14.2 : 1.0
#                  suffix3 = 'ita'          female : male   =     14.1 : 1.0
#                  suffix2 = 'ro'             male : female =     13.9 : 1.0
#                  suffix3 = 'dra'          female : male   =     13.1 : 1.0
#                  suffix1 = 'p'              male : female =     12.6 : 1.0
#                  prefix3 = 'Cat'          female : male   =     12.2 : 1.0
#                  suffix3 = 'ert'            male : female =     11.7 : 1.0
#                  suffix3 = 'ria'          female : male   =     11.4 : 1.0
#                  suffix3 = 'nni'          female : male   =     11.0 : 1.0
#       end_vowel_digraphs = 'ew'             male : female =     10.8 : 1.0
#                  prefix3 = 'Dor'          female : male   =     10.6 : 1.0
#                  prefix2 = 'Tu'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ya'             male : female =     10.6 : 1.0
#                  prefix2 = 'Ce'           female : male   =     10.6 : 1.0
#                  suffix2 = 'ip'             male : female =     10.6 : 1.0
#                  suffix2 = 'em'             male : female =     10.6 : 1.0
#                  suffix2 = 'ew'             male : female =     10.6 : 1.0
#                  suffix1 = 'v'              male : female =     10.5 : 1.0
#                  suffix3 = 'son'            male : female =     10.5 : 1.0
#                  prefix3 = 'Ros'          female : male   =     10.4 : 1.0
#                  suffix2 = 'im'             male : female =     10.3 : 1.0
#                  prefix3 = 'Rod'            male : female =     10.3 : 1.0
#                  suffix1 = 'o'              male : female =     10.0 : 1.0
#                  suffix1 = 'd'              male : female =      9.9 : 1.0
#                  suffix3 = 'han'            male : female =      9.8 : 1.0
#                  suffix3 = 'dor'            male : female =      9.8 : 1.0
#                  suffix3 = 'cia'          female : male   =      9.7 : 1.0
#                  prefix3 = 'Jen'          female : male   =      9.6 : 1.0
#                  prefix3 = 'Gar'            male : female =      9.6 : 1.0
#                  suffix2 = 'ns'             male : female =      9.4 : 1.0
#                  suffix2 = 'rn'             male : female =      9.4 : 1.0
#                  suffix2 = 'ff'             male : female =      9.4 : 1.0
#                  suffix2 = 'ya'           female : male   =      9.4 : 1.0
#                  suffix2 = 'as'             male : female =      9.2 : 1.0
#                  suffix1 = 'm'              male : female =      9.2 : 1.0
#                  suffix2 = 'ti'           female : male   =      9.0 : 1.0
#           vowel_digraphs = 'ew'             male : female =      9.0 : 1.0
#                  suffix3 = 'ler'            male : female =      8.8 : 1.0
#                  suffix3 = 'ias'            male : female =      8.8 : 1.0
#                  suffix3 = 'den'            male : female =      8.8 : 1.0
#                  suffix2 = 'on'             male : female =      8.6 : 1.0
#                  suffix3 = 'lyn'          female : male   =      8.6 : 1.0
#             end_digraphs = 'st'             male : female =      8.5 : 1.0
#           start_digraphs = 'wh'             male : female =      8.5 : 1.0
#                  prefix2 = 'Wh'             male : female =      8.4 : 1.0
#                  suffix2 = 'st'             male : female =      8.3 : 1.0
#                  suffix2 = 'rk'             male : female =      8.3 : 1.0
#                  suffix2 = 'ul'             male : female =      8.3 : 1.0
#                  suffix3 = 'ter'            male : female =      8.3 : 1.0
#                  suffix2 = 'ea'           female : male   =      8.3 : 1.0
#                  suffix2 = 'di'           female : male   =      8.3 : 1.0
#                  suffix3 = 'lle'          female : male   =      8.2 : 1.0
#                  suffix2 = 'er'             male : female =      8.2 : 1.0
#       end_vowel_digraphs = 'ea'           female : male   =      8.1 : 1.0
#                  prefix3 = 'God'            male : female =      7.8 : 1.0
#                  prefix3 = 'For'            male : female =      7.8 : 1.0
#                  prefix3 = 'Par'            male : female =      7.8 : 1.0
#                  prefix3 = 'Lor'          female : male   =      7.8 : 1.0
#                  suffix3 = 'ven'            male : female =      7.7 : 1.0
#                  suffix3 = 'uel'            male : female =      7.7 : 1.0
#                  suffix3 = 'las'            male : female =      7.7 : 1.0
#                  suffix3 = 'lli'          female : male   =      7.5 : 1.0
#                  prefix3 = 'Mal'          female : male   =      7.5 : 1.0
#                  suffix2 = 'am'             male : female =      7.4 : 1.0
#                  suffix3 = 'ene'          female : male   =      7.4 : 1.0
#                  prefix2 = 'Wa'             male : female =      7.4 : 1.0
#                  suffix3 = 'bel'          female : male   =      7.1 : 1.0
#                  suffix2 = 'sy'           female : male   =      7.1 : 1.0
#           vowel_digraphs = 'oo'             male : female =      6.9 : 1.0
#                  suffix3 = 'lee'          female : male   =      6.9 : 1.0
#                  prefix3 = 'Kar'          female : male   =      6.9 : 1.0
#                  prefix3 = 'Whi'            male : female =      6.8 : 1.0
#                  prefix3 = 'Bur'            male : female =      6.8 : 1.0
#                  prefix3 = 'Kin'            male : female =      6.8 : 1.0
# correct=female guess=male name=Adelind
# correct=female guess=male name=Alex
# correct=female guess=male name=Andrei
# correct=female guess=male name=Aubrey
# correct=female guess=male name=Aubry
# correct=female guess=male name=Austin
# correct=female guess=male name=Ayn
# correct=female guess=male name=Bobby
# correct=female guess=male name=Brett
# correct=female guess=male name=Brigid
# correct=female guess=male name=Charlot
# correct=female guess=male name=Cherey
# correct=female guess=male name=Christen
# correct=female guess=male name=Ealasaid
# correct=female guess=male name=Francis
# correct=female guess=male name=Georgiamay
# correct=female guess=male name=Hally
# correct=female guess=male name=Hannis
# correct=female guess=male name=Havivah
# correct=female guess=male name=Hephzibah
# correct=female guess=male name=Hilliary
# correct=female guess=male name=Janifer
# correct=female guess=male name=Jonell
# correct=female guess=male name=Lesly
# correct=female guess=male name=Lois
# correct=female guess=male name=Mead
# correct=female guess=male name=Meaghan
# correct=female guess=male name=Meghan
# correct=female guess=male name=Orel
# correct=female guess=male name=Paula-Grace
# correct=female guess=male name=Phillis
# correct=female guess=male name=Pru
# correct=female guess=male name=Rhianon
# correct=female guess=male name=Rosario
# correct=female guess=male name=Sam
# correct=female guess=male name=Stacey
# correct=female guess=male name=Stacy
# correct=female guess=male name=Storm
# correct=female guess=male name=Tracey
# correct=male guess=female name=Abbey
# correct=male guess=female name=Allah
# correct=male guess=female name=Allin
# correct=male guess=female name=Allyn
# correct=male guess=female name=Angel
# correct=male guess=female name=Archie
# correct=male guess=female name=Artie
# correct=male guess=female name=Ave
# correct=male guess=female name=Barrie
# correct=male guess=female name=Billie
# correct=male guess=female name=Boniface
# correct=male guess=female name=Bryce
# correct=male guess=female name=Cass
# correct=male guess=female name=Cecil
# correct=male guess=female name=Chrissy
# correct=male guess=female name=Constantine
# correct=male guess=female name=Dennie
# correct=male guess=female name=Donn
# correct=male guess=female name=Ellis
# correct=male guess=female name=Farley
# correct=male guess=female name=Felipe
# correct=male guess=female name=Giorgi
# correct=male guess=female name=Godfree
# correct=male guess=female name=Isa
# correct=male guess=female name=Karsten
# correct=male guess=female name=Kelly
# correct=male guess=female name=Lanny
# correct=male guess=female name=Lindy
# correct=male guess=female name=Loren
# correct=male guess=female name=Lorne
# correct=male guess=female name=Martie
# correct=male guess=female name=Michele
# correct=male guess=female name=Mischa
# correct=male guess=female name=Moise
# correct=male guess=female name=Monte
# correct=male guess=female name=Nathaniel
# correct=male guess=female name=Odell
# correct=male guess=female name=Pearce
# correct=male guess=female name=Ronny
# correct=male guess=female name=Selby
# correct=male guess=female name=Seth
# correct=male guess=female name=Sunny
# correct=male guess=female name=Tally
# correct=male guess=female name=Tammy
# correct=male guess=female name=Tate
# correct=male guess=female name=Teddie
# correct=male guess=female name=Timmy
# correct=male guess=female name=Tonnie
